# %% [markdown]
# <a href="https://colab.research.google.com/github/osoliman/DSC110/blob/main/Description/DSC110_Description_Cleaning_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %%
import pandas as pd

# %% [markdown]
# # **Loading files**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/osoliman/DSC110/refs/heads/main/Datasets/nhanes_final.csv')

# %% [markdown]
# # **Operations on DataFrames**

# %%
#show top 5 rows
df.head()
# Out:
#          id  gender   age  race_ethnicity education   bmi  height_cm  \
# 0  130378.0     1.0  43.0             6.0       5.0  27.0      179.5
# 1  130379.0     1.0  66.0             3.0       5.0  33.5      174.2
# 2  130380.0     2.0  44.0             2.0       3.0  29.7      152.9
# 3  130381.0     2.0   5.0             7.0      None  23.8      120.1
# 4  130382.0     1.0   2.0             3.0      None   NaN        NaN
#
#    systolic_bp has_diabetes  hba1c  fasting_glucose education_label
# 0        135.0          2.0    5.6            113.0             NaN
# 1        121.0          2.0    5.6             99.0             NaN
# 2        111.0          1.0    6.2            156.0             NaN
# 3          NaN          2.0    NaN              NaN             NaN
# 4          NaN          2.0    NaN              NaN             NaN

# %%
df.head(1)
# Out:
#          id  gender   age  race_ethnicity education   bmi  height_cm  \
# 0  130378.0     1.0  43.0             6.0       5.0  27.0      179.5
#
#    systolic_bp has_diabetes  hba1c  fasting_glucose education_label
# 0        135.0          2.0    5.6            113.0             NaN

# %%
df.tail()
# Out:
#              id  gender   age  race_ethnicity  education   bmi  height_cm  \
# 11928  142306.0     1.0   9.0             2.0        NaN  15.4      128.0
# 11929  142307.0     2.0  49.0             4.0        5.0   NaN      143.8
# 11930  142308.0     1.0  50.0             2.0        4.0  26.4      173.3
# 11931  142309.0     1.0  40.0             2.0        4.0  25.5      179.1
# 11932  142310.0     2.0  80.0             3.0        3.0  27.6      161.7
#
#        systolic_bp  has_diabetes  hba1c  fasting_glucose
# 11928          NaN           2.0    NaN              NaN
# 11929        127.0           1.0    6.2              NaN
# 11930        106.0           2.0    NaN              NaN
# 11931        127.0           2.0    5.2             96.0
# 11932        128.0           2.0    5.3              NaN

# %%
df.shape
# Out:
# (11933, 11)

# %%
df.shape[0]
# Out:
# 11933

# %%
print(f'this file has {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# this file has 11933 rows and 11 columns

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# Missing Values
# - Find fields with missing values
# - Drop missing values
# - Replace missing values with mean

# %%
#Boolean
1+1==2
# Out:
# True

# %%
1+1==3
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(1+1==2)
# Out:
# 1

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# race_ethnicity         0
# education              0
# bmi                 3462
# height_cm           3434
# systolic_bp         4416
# has_diabetes           0
# hba1c               5218
# fasting_glucose     8261
# education_label    11933
# dtype: int64

# %%
df.isna().mean() * 100
# Out:
# id                   0.000000
# gender               0.000000
# age                  0.000000
# race_ethnicity       0.000000
# education            0.000000
# bmi                 29.011984
# height_cm           28.777340
# systolic_bp         37.006620
# has_diabetes         0.000000
# hba1c               43.727478
# fasting_glucose     69.228191
# education_label    100.000000
# dtype: float64

# %%
# Drop rows where has_diabetes is missing
df_clean = df.dropna(subset=['has_diabetes']).copy()

# Check how many rows you lost
print(f"Started with {len(df)} rows")
print(f"Now have {len(df_clean)} rows")
# Out:
# Started with 11933 rows
# Now have 11933 rows

# %%
#Fill missing systolic_bp with mean
mean_bp = df_clean['systolic_bp'].mean()
df_clean['systolic_bp'] = df_clean['systolic_bp'].fillna(mean_bp)

# %%
# Check it worked - should be 0 now
df_clean['systolic_bp'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Transform variables

# %%
# Create BMI categories
df['bmi_category'] = pd.cut(df['bmi'],
                             bins=[0, 18.5, 25, 30, 100],
                             labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# Check it worked
df['bmi_category'].value_counts()
# Out:
# bmi_category
# Obese          2666
# Normal         2400
# Overweight     2189
# Underweight    1216
# Name: count, dtype: int64

# %%
df['education'].unique()
# Out:
# array(['5.0', '3.0', 'None', '2.0', '4.0', '1.0', '9.0'], dtype=object)

# %%
# Create a mapping dictionary (adjust based on your data dictionary)
education_map = {
    '1.0': 'Less than 9th grade',
    '2.0': '9-11th grade',
    '3.0': 'High school grad',
    '4.0': 'Some college or AA degree',
    '5.0': 'College graduate',
    '9.0': 'Do not know',
    'None': 'Missing'
}
# Apply the mapping
df['education_label'] = df['education'].map(education_map)

# %%
# Check it worked
df['education_label'].value_counts()
# Out:
# education_label
# Missing                      4139
# College graduate             2625
# Some college or AA degree    2370
# High school grad             1749
# 9-11th grade                  666
# Less than 9th grade           373
# Do not know                    11
# Name: count, dtype: int64

# %% [markdown]
# # **Data Summarization**

# %% [markdown]
# Numeric

# %%
# Calculate mean
df['systolic_bp'].mean()

# Calculate standard deviation
df['systolic_bp'].std()

# Or get both at once
df['systolic_bp'].describe()
# Out:
# count    7517.000000
# mean      119.288546
# std        18.561052
# min        61.000000
# 25%       106.000000
# 50%       117.000000
# 75%       130.000000
# max       232.000000
# Name: systolic_bp, dtype: float64

# %%
# Median
df['age'].median()
# Out:
# 37.0

# %%
# IQR - just the 25th and 75th percentiles
df['age'].quantile([0.25, 0.75])
# Out:
# 0.25    13.0
# 0.75    62.0
# Name: age, dtype: float64

# %%
# Or all at once
df['age'].describe()

# %%
df['age'].mode()
# Out:
# 0    80.0
# Name: age, dtype: float64

# %% [markdown]
# Categorical
#
# One Variable

# %%
# Simple counts
df['education_label'].value_counts()
# Out:
# education_label
# College graduate       33.727354
# Some college           30.450983
# High school grad       22.472054
# 9-11th grade            8.557112
# Less than 9th grade     4.792496
# Name: proportion, dtype: float64

# %%
# With percentages
df['education_label'].value_counts(normalize=True) * 100

# %% [markdown]
# Categorical
#
# Two Variables

# %%
# Create cross-tabulation
pd.crosstab(df['has_diabetes'], df['bmi_category'])
# Out:
# bmi_category  Underweight  Normal  Overweight  Obese
# has_diabetes
# 1.0                     4     109         233    504
# 2.0                  1211    2251        1886   2042
# 3.0                     0      39          70    120
# 9.0                     1       1           0      0

# %%
# With row percentages (more useful clinically)
pd.crosstab(df['has_diabetes'], df['bmi_category'], normalize='index') * 100
# Out:
# bmi_category  Underweight     Normal  Overweight      Obese
# has_diabetes
# 1.0              0.470588  12.823529   27.411765  59.294118
# 2.0             16.387009  30.460081   25.520974  27.631935
# 3.0              0.000000  17.030568   30.567686  52.401747
# 9.0             50.000000  50.000000    0.000000   0.000000

# %% [markdown]
# Mix of variables

# %%
#df.groupby('grouping_variable')['numeric_variable'].calculation()
df.groupby('has_diabetes')['bmi'].mean()
# Out:
# has_diabetes
# 1.0     32.981412
# 2.0     26.439797
# 3.0     32.068559
# 9.0     19.250000
# None          NaN
# Name: bmi, dtype: float64
