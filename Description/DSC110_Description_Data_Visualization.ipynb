# %% [markdown]
# <a href="https://colab.research.google.com/github/osoliman/DSC110/blob/main/Description/DSC110_Description_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Visualization**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/osoliman/DSC110/refs/heads/main/Datasets/nhanes_final.csv')

# %% [markdown]
# One Numerical Variable

# %%
df['bmi'].hist()
# Out:
# <Axes: >

# %% [markdown]
# One Categorical Variable

# %%
df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# Two Numerical Variables

# %%
df.plot(x='fasting_glucose', y='hba1c', kind='scatter')
# Out:
# <Axes: xlabel='fasting_glucose', ylabel='hba1c'>

# %% [markdown]
# Two Categorical Variables

# %%
pd.crosstab(df['gender'], df['has_diabetes']).plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# One Numerical and One Categorical

# %%
df.boxplot(column='bmi', by='gender')
# Out:
# <Axes: title={'center': 'bmi'}, xlabel='gender'>

# %% [markdown]
# Making it more professionally looking

# %%
#One Numerical Variable
df['bmi'].hist()
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Number of Respondents')
# Out:
# Text(0, 0.5, 'Number of Respondents')

# %% [markdown]
# More
#
# Violin Charts
#
# Heatmap
